# %%
MODEL_CLS = "ncf"
COMB = "att"
POOLING = "sum"
HIDDEN_DIM = (
    [128, 64, 32]
    if COMB=="cat"
    else [64, 32]
)
DATASET = "movielens"
STRATEGY = "pointwise"
PATH_WORK_DIR = "../.."

# %%
NUM_USERS = 609
NUM_ITEMS = 8452
NUM_GENRES = 19

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PROJECT\M3-PJT_RS

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Config

# %%
import pandas as pd
import torch
from components import feature_store
from pointwiseBayes import config, datamodule, trainer, evaluator, utils
import lfm

# %%
PATH = f"./config/{MODEL_CLS}_{STRATEGY}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/ratings.csv"
df = pd.read_csv(PATH)

# %%
kwargs = dict(
    df=df,
    percentile=0.9,
)

utils.desc.main(**kwargs)
# Out:
# number of user: 609
# number of item: 8452
# total interaction: 81763
# interaction density: 1.5885 %
# max interaction of user: 2117
# max interaction of item: 315
# top 10.0 % interaction of user: 344.4
# top 10.0 % interaction of item: 25.0
# mean interaction of user: 134
# mean interaction of item: 9

# %%
kwargs = dict(
    df=df,
    cfg=cfg.datamodule,
)

dataloaders, _ = datamodule.build(**kwargs)

# %%
PATH = "./data/genres.pt"
genres = torch.load(PATH)

# %%
feature_store_cls = feature_store.FeatureStore()

kwargs = dict(
    name="genre",
    entity="item",
    data=genres,
)
feature_store_cls.register(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    feature_store=feature_store_cls,
    num_users=NUM_USERS,
    num_items=NUM_ITEMS,
    num_genres=NUM_GENRES,
    hidden_dim=HIDDEN_DIM,
    comb=COMB,
    pooling=POOLING,
    **cfg.model.params,
)

model = lfm.ncf.NeuralCollaborativeFiltering(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 21
# BEST SCORE: 0.4714

# %%
kwargs = dict(
    records=records,
    suptitle="NCF Training History",
    trn="BCE",
    val="NDCG@10",
    figsize=(7,3),
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    cutoff=[5,10,15,20,25,50],
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 799/799 [00:08<00:00, 98.04it/s]

# %%
metrics_sheet
# Out:
#     k  hit_ratio  precision    recall       map      ndcg
# 0   5   0.845395   0.365461  0.315018  0.233987  0.449618
# 1  10   0.944079   0.280099  0.447443  0.282717  0.467215
# 2  15   0.958882   0.232456  0.514134  0.303558  0.481911
# 3  20   0.981908   0.199095  0.573647  0.315540  0.495389
# 4  25   0.986842   0.176645  0.609476  0.323049  0.505103
# 5  50   0.996711   0.117632  0.714825  0.340819  0.537421

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{MODEL_CLS}/{COMB}_{POOLING}_{STRATEGY}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
