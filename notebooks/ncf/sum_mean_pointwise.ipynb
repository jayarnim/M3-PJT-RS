# %%
MODEL_CLS = "ncf"
COMB = "sum"
POOLING = "mean"
HIDDEN_DIM = (
    [128, 64, 32]
    if COMB=="cat"
    else [64, 32]
)
DATASET = "movielens"
STRATEGY = "pointwise"
PATH_WORK_DIR = "../.."

# %%
NUM_USERS = 609
NUM_ITEMS = 8452
NUM_GENRES = 19

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.chdir(PATH_WORK_DIR)
print(f"DIRECTORY: {os.getcwd()}")
# Out:
# DIRECTORY: c:\Users\jayar\Desktop\바탕 화면\REPO\PROJECT\M3-PJT_RS

# %%
import sys
sys.path.append("src")

# %% [markdown]
# # Config

# %%
import pandas as pd
import torch
from components import feature_store
from pointwiseBayes import config, datamodule, trainer, evaluator, utils
import lfm

# %%
PATH = f"./config/{MODEL_CLS}_{STRATEGY}.yaml"
cfg = config.build(PATH)

# %%
utils.seed.main(cfg.seed)
# Out:
# ALL SEEDS RESET: 42

# %% [markdown]
# # Data Preparation

# %%
PATH = f"./data/ratings.csv"
df = pd.read_csv(PATH)

# %%
kwargs = dict(
    df=df,
    percentile=0.9,
)

utils.desc.main(**kwargs)
# Out:
# number of user: 609
# number of item: 8452
# total interaction: 81763
# interaction density: 1.5885 %
# max interaction of user: 2117
# max interaction of item: 315
# top 10.0 % interaction of user: 344.4
# top 10.0 % interaction of item: 25.0
# mean interaction of user: 134
# mean interaction of item: 9

# %%
kwargs = dict(
    df=df,
    cfg=cfg.datamodule,
)

dataloaders, _ = datamodule.build(**kwargs)

# %%
PATH = "./data/genres.pt"
genres = torch.load(PATH)

# %%
feature_store_cls = feature_store.FeatureStore()

kwargs = dict(
    name="genre",
    entity="item",
    data=genres,
)
feature_store_cls.register(**kwargs)

# %% [markdown]
# # Modeling

# %%
kwargs = dict(
    feature_store=feature_store_cls,
    num_users=NUM_USERS,
    num_items=NUM_ITEMS,
    num_genres=NUM_GENRES,
    hidden_dim=HIDDEN_DIM,
    comb=COMB,
    pooling=POOLING,
    **cfg.model.params,
)

model = lfm.ncf.NeuralCollaborativeFiltering(**kwargs)

# %% [markdown]
# # Train

# %%
kwargs = dict(
    model=model,
    cfg=cfg.trainer,
)

opt = trainer.build(**kwargs)

# %%
kwargs = dict(
    trn_loader=dataloaders["trn"],
    val_loader=dataloaders["val"],
)

records = opt.fit(**kwargs)
# Out:
# BEST EPOCH: 27
# BEST SCORE: 0.4779

# %%
kwargs = dict(
    records=records,
    suptitle="NCF Training History",
    trn="BCE",
    val="NDCG@10",
    figsize=(7,3),
)

utils.visualizer.main(**kwargs)

# %% [markdown]
# # Test

# %%
kwargs = dict(
    model=model,
    cutoff=[5,10,15,20,25,50],
)

msr = evaluator.build(**kwargs)

# %%
result, metrics_sheet = msr(dataloaders["tst"])
# Out:
# TST: 100%|██████████| 799/799 [00:06<00:00, 128.61it/s]

# %%
metrics_sheet
# Out:
#     k  hit_ratio  precision    recall       map      ndcg
# 0   5   0.840461   0.363158  0.313788  0.228589  0.448024
# 1  10   0.942434   0.283882  0.452244  0.281217  0.470018
# 2  15   0.963816   0.235526  0.528065  0.302282  0.486448
# 3  20   0.975329   0.200411  0.572721  0.312945  0.495849
# 4  25   0.985197   0.177829  0.607243  0.320443  0.505104
# 5  50   0.995066   0.119309  0.719956  0.339333  0.539634

# %% [markdown]
# # Save

# %%
PATH = f'./checkpoints/{MODEL_CLS}/{COMB}_{POOLING}_{STRATEGY}.pth'

kwargs = dict(
    obj=model,
    path=PATH,
)

utils.checkpointer.save(**kwargs)
